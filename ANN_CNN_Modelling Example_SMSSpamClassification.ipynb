# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:/Users/micha/yelp.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   business_id  10000 non-null  object
#  1   date         10000 non-null  object
#  2   review_id    10000 non-null  object
#  3   stars        10000 non-null  int64
#  4   text         10000 non-null  object
#  5   type         10000 non-null  object
#  6   user_id      10000 non-null  object
#  7   cool         10000 non-null  int64
#  8   useful       10000 non-null  int64
#  9   funny        10000 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 781.4+ KB

# %%
#Rule for NN when it comes to text data
#1. ANN/CNN understands only padded sequence(NUMBERS) (You need to represent text data into numbers)
#2. Input Size(Number of Tokens) must be FIXED
#3. Labels must be discrete numerical/binarized

# %%
data['stars'] = data['stars'].map({1:0, 2:0, 3:1, 4:1, 5:1})

# %%
data.head()
# Out:
#               business_id        date               review_id  stars  \
# 0  9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      1
# 1  ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      1
# 2  6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      1
# 3  _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      1
# 4  6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      1
#
#                                                 text    type  \
# 0  My wife took me here on my birthday for breakf...  review
# 1  I have no idea why some people give bad review...  review
# 2  love the gyro plate. Rice is so good and I als...  review
# 3  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...  review
# 4  General Manager Scott Petello is a good egg!!!...  review
#
#                   user_id  cool  useful  funny
# 0  rLtl8ZkDX5vH5nAx9C3q5Q     2       5      0
# 1  0a2KyEL0d3Yb1V6aivbIuQ     0       0      0
# 2  0hT2KtfLiobPvh6cDC8JQg     0       1      0
# 3  uZetl9T0NcROGOyFfughhg     1       2      0
# 4  vYmM4KTsC8ZfQBg-j5MWkw     0       0      0

# %%
#Seperate data as features and label
features = data.text.values
label = data.stars.values

# %%
label.shape
# Out:
# (10000,)

# %%
#Train test split

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(features,
                                                 label,
                                                 test_size=0.2,
                                                 random_state=1)

# %%
#Start with Tokenization
from tensorflow.keras.preprocessing.text import Tokenizer

#Decide the Vocabulary Word Frequency Size. Used only when Regularization is required

vocabFreqWordSize = None

#Convert the sentences into sequence of words

tokenizer = Tokenizer(num_words=vocabFreqWordSize, oov_token="<DontKnow>", split=" ")

#Fit tokenizer with training set

tokenizer.fit_on_texts(X_train)

# %%
tokenizer.word_index
# Out:
# {'<DontKnow>': 1,
#  'the': 2,
#  'and': 3,
#  'a': 4,
#  'i': 5,
#  'to': 6,
#  'of': 7,
#  'was': 8,
#  'is': 9,
#  'it': 10,
#  'for': 11,
#  'in': 12,
#  'that': 13,
#  'my': 14,
#  'with': 15,
#  'but': 16,
#  'you': 17,
#  'this': 18,
#  'they': 19,
#  'on': 20,
#  'we': 21,
#  'have': 22,
#  'not': 23,
#  'had': 24,
#  'are': 25,
#  'good': 26,
#  'so': 27,
#  'place': 28,
#  'at': 29,
#  'food': 30,
#  'were': 31,
#  'as': 32,
#  'be': 33,
#  'there': 34,
#  'great': 35,
#  'like': 36,
#  'if': 37,
#  'all': 38,
#  'me': 39,
#  'just': 40,
#  'out': 41,
#  'very': 42,
#  'here': 43,
#  'one': 44,
#  'their': 45,
#  'or': 46,
#  'get': 47,
#  "it's": 48,
#  'from': 49,
#  'up': 50,
#  'when': 51,
#  'go': 52,
#  'time': 53,
#  'really': 54,
#  'our': 55,
#  'some': 56,
#  'about': 57,
#  'service': 58,
#  'would': 59,
#  'what': 60,
#  'an': 61,
#  'your': 62,
#  'can': 63,
#  'been': 64,
#  'which': 65,
#  'back': 66,
#  'more': 67,
#  'only': 68,
#  'also': 69,
#  'no': 70,
#  'will': 71,
#  "don't": 72,
#  'by': 73,
#  'too': 74,
#  'love': 75,
#  'has': 76,
#  'little': 77,
#  'nice': 78,
#  "i'm": 79,
#  'well': 80,
#  'other': 81,
#  "i've": 82,
#  'because': 83,
#  'them': 84,
#  'always': 85,
#  'even': 86,
#  'do': 87,
#  'than': 88,
#  'best': 89,
#  'us': 90,
#  'he': 91,
#  'after': 92,
#  'got': 93,
#  'pretty': 94,
#  'chicken': 95,
#  'she': 96,
#  'much': 97,
#  'try': 98,
#  'restaurant': 99,
#  'ordered': 100,
#  'menu': 101,
#  'people': 102,
#  'know': 103,
#  'order': 104,
#  'bar': 105,
#  'first': 106,
#  'over': 107,
#  'could': 108,
#  "didn't": 109,
#  'never': 110,
#  'think': 111,
#  'friendly': 112,
#  'better': 113,
#  'went': 114,
#  'make': 115,
#  'staff': 116,
#  'night': 117,
#  'am': 118,
#  'did': 119,
#  'way': 120,
#  'then': 121,
#  'off': 122,
#  'going': 123,
#  'how': 124,
#  'cheese': 125,
#  '2': 126,
#  'who': 127,
#  'right': 128,
#  'delicious': 129,
#  'two': 130,
#  'pizza': 131,
#  'made': 132,
#  'few': 133,
#  'salad': 134,
#  'say': 135,
#  'came': 136,
#  'now': 137,
#  'want': 138,
#  'any': 139,
#  'lunch': 140,
#  'come': 141,
#  'fresh': 142,
#  'again': 143,
#  'sauce': 144,
#  '5': 145,
#  'day': 146,
#  'new': 147,
#  'still': 148,
#  'take': 149,
#  '3': 150,
#  'down': 151,
#  'happy': 152,
#  'see': 153,
#  'definitely': 154,
#  'sure': 155,
#  'while': 156,
#  'eat': 157,
#  'since': 158,
#  'experience': 159,
#  'before': 160,
#  'wait': 161,
#  'around': 162,
#  'times': 163,
#  'though': 164,
#  'amazing': 165,
#  'something': 166,
#  'meal': 167,
#  'find': 168,
#  'her': 169,
#  'ever': 170,
#  'bit': 171,
#  'every': 172,
#  'give': 173,
#  'most': 174,
#  "can't": 175,
#  'everything': 176,
#  'next': 177,
#  'bad': 178,
#  'area': 179,
#  'table': 180,
#  'said': 181,
#  'many': 182,
#  'lot': 183,
#  'where': 184,
#  'into': 185,
#  'hour': 186,
#  'its': 187,
#  'last': 188,
#  'being': 189,
#  'thing': 190,
#  'dinner': 191,
#  'another': 192,
#  'location': 193,
#  'side': 194,
#  'phoenix': 195,
#  '4': 196,
#  'small': 197,
#  'both': 198,
#  'big': 199,
#  'home': 200,
#  'prices': 201,
#  'sandwich': 202,
#  'favorite': 203,
#  'drinks': 204,
#  'drink': 205,
#  "you're": 206,
#  'his': 207,
#  'tasty': 208,
#  "wasn't": 209,
#  'stars': 210,
#  'fries': 211,
#  'things': 212,
#  'sweet': 213,
#  'beer': 214,
#  'burger': 215,
#  'long': 216,
#  'awesome': 217,
#  'hot': 218,
#  'wine': 219,
#  'enough': 220,
#  'feel': 221,
#  '1': 222,
#  'worth': 223,
#  'looking': 224,
#  'minutes': 225,
#  'atmosphere': 226,
#  'price': 227,
#  'bread': 228,
#  'coffee': 229,
#  'tried': 230,
#  'need': 231,
#  'store': 232,
#  'took': 233,
#  'should': 234,
#  'clean': 235,
#  'ok': 236,
#  'places': 237,
#  'different': 238,
#  'old': 239,
#  'meat': 240,
#  '10': 241,
#  'room': 242,
#  'work': 243,
#  'selection': 244,
#  "that's": 245,
#  'actually': 246,
#  'breakfast': 247,
#  'taste': 248,
#  'years': 249,
#  'asked': 250,
#  'check': 251,
#  'friends': 252,
#  'excellent': 253,
#  'huge': 254,
#  'recommend': 255,
#  'these': 256,
#  'visit': 257,
#  'found': 258,
#  'kind': 259,
#  'nothing': 260,
#  'free': 261,
#  'flavor': 262,
#  'probably': 263,
#  'those': 264,
#  'quality': 265,
#  'same': 266,
#  'wanted': 267,
#  'quite': 268,
#  'thought': 269,
#  'anything': 270,
#  'super': 271,
#  'sushi': 272,
#  'however': 273,
#  'maybe': 274,
#  'perfect': 275,
#  'cool': 276,
#  'server': 277,
#  'large': 278,
#  'look': 279,
#  'once': 280,
#  'special': 281,
#  'full': 282,
#  'friend': 283,
#  'scottsdale': 284,
#  'beef': 285,
#  'town': 286,
#  'fun': 287,
#  'cream': 288,
#  "i'd": 289,
#  'house': 290,
#  'top': 291,
#  'why': 292,
#  'rice': 293,
#  "i'll": 294,
#  'each': 295,
#  'usually': 296,
#  'dish': 297,
#  'told': 298,
#  'parking': 299,
#  'review': 300,
#  'far': 301,
#  'inside': 302,
#  'outside': 303,
#  'away': 304,
#  'fried': 305,
#  'enjoy': 306,
#  'items': 307,
#  'high': 308,
#  'half': 309,
#  'used': 310,
#  'spot': 311,
#  'oh': 312,
#  'without': 313,
#  'open': 314,
#  'decided': 315,
#  'left': 316,
#  'everyone': 317,
#  'soup': 318,
#  'else': 319,
#  'overall': 320,
#  'pork': 321,
#  'spicy': 322,
#  'served': 323,
#  'least': 324,
#  'ice': 325,
#  'ask': 326,
#  'music': 327,
#  'enjoyed': 328,
#  'decent': 329,
#  'couple': 330,
#  'water': 331,
#  'course': 332,
#  'getting': 333,
#  'almost': 334,
#  'family': 335,
#  'having': 336,
#  'dishes': 337,
#  'loved': 338,
#  'through': 339,
#  'three': 340,
#  'star': 341,
#  'put': 342,
#  'makes': 343,
#  'patio': 344,
#  'eating': 345,
#  'yes': 346,
#  'may': 347,
#  'red': 348,
#  'fish': 349,
#  'whole': 350,
#  'mexican': 351,
#  'husband': 352,
#  'fantastic': 353,
#  'such': 354,
#  'plate': 355,
#  'hard': 356,
#  'does': 357,
#  'green': 358,
#  'wonderful': 359,
#  'use': 360,
#  'fan': 361,
#  'restaurants': 362,
#  'dining': 363,
#  'busy': 364,
#  'part': 365,
#  'tacos': 366,
#  'week': 367,
#  'him': 368,
#  'valley': 369,
#  'chips': 370,
#  'shrimp': 371,
#  'stuff': 372,
#  'must': 373,
#  'fast': 374,
#  'shop': 375,
#  'less': 376,
#  '6': 377,
#  'reviews': 378,
#  'during': 379,
#  'care': 380,
#  'tasted': 381,
#  "isn't": 382,
#  'either': 383,
#  'chocolate': 384,
#  'several': 385,
#  'let': 386,
#  'looked': 387,
#  'done': 388,
#  'kids': 389,
#  'close': 390,
#  'own': 391,
#  'hours': 392,
#  'local': 393,
#  'liked': 394,
#  "doesn't": 395,
#  'customer': 396,
#  'live': 397,
#  'business': 398,
#  'steak': 399,
#  'style': 400,
#  'yet': 401,
#  'door': 402,
#  'although': 403,
#  'especially': 404,
#  'sit': 405,
#  'quick': 406,
#  'dessert': 407,
#  'tables': 408,
#  'tell': 409,
#  'end': 410,
#  'might': 411,
#  'finally': 412,
#  'cheap': 413,
#  'line': 414,
#  'real': 415,
#  'waitress': 416,
#  'cooked': 417,
#  'yummy': 418,
#  'year': 419,
#  'guy': 420,
#  'disappointed': 421,
#  'name': 422,
#  'someone': 423,
#  'drive': 424,
#  'stop': 425,
#  'coming': 426,
#  'trying': 427,
#  'decor': 428,
#  'thai': 429,
#  'comes': 430,
#  'yelp': 431,
#  'gave': 432,
#  'bring': 433,
#  'fact': 434,
#  '30': 435,
#  'walk': 436,
#  'lots': 437,
#  'bbq': 438,
#  'extra': 439,
#  'started': 440,
#  'keep': 441,
#  'plus': 442,
#  'tea': 443,
#  '20': 444,
#  "won't": 445,
#  'until': 446,
#  'pay': 447,
#  'front': 448,
#  'reason': 449,
#  'street': 450,
#  'walked': 451,
#  'wrong': 452,
#  'white': 453,
#  'today': 454,
#  'deal': 455,
#  'seemed': 456,
#  "there's": 457,
#  'owner': 458,
#  'call': 459,
#  'instead': 460,
#  'called': 461,
#  'brought': 462,
#  'bacon': 463,
#  'salsa': 464,
#  'helpful': 465,
#  'okay': 466,
#  'sat': 467,
#  'seems': 468,
#  'etc': 469,
#  'able': 470,
#  'potato': 471,
#  'often': 472,
#  'regular': 473,
#  'waiting': 474,
#  'myself': 475,
#  'car': 476,
#  "couldn't": 477,
#  'money': 478,
#  'waiter': 479,
#  'job': 480,
#  'felt': 481,
#  'offer': 482,
#  'kitchen': 483,
#  'guess': 484,
#  'glass': 485,
#  'return': 486,
#  'group': 487,
#  'second': 488,
#  'person': 489,
#  'wife': 490,
#  'needed': 491,
#  'saw': 492,
#  'highly': 493,
#  'options': 494,
#  'seem': 495,
#  'beans': 496,
#  "they're": 497,
#  'sandwiches': 498,
#  'light': 499,
#  'help': 500,
#  'fine': 501,
#  'wish': 502,
#  'hotel': 503,
#  'impressed': 504,
#  'serve': 505,
#  '7': 506,
#  'gets': 507,
#  'ago': 508,
#  'pick': 509,
#  'rolls': 510,
#  'dog': 511,
#  'roll': 512,
#  "wouldn't": 513,
#  'absolutely': 514,
#  'portions': 515,
#  'type': 516,
#  'ate': 517,
#  'seating': 518,
#  'list': 519,
#  'later': 520,
#  'four': 521,
#  'warm': 522,
#  'choice': 523,
#  'point': 524,
#  '8': 525,
#  'expect': 526,
#  'size': 527,
#  'appetizer': 528,
#  'mall': 529,
#  'priced': 530,
#  'perfectly': 531,
#  'bowl': 532,
#  '15': 533,
#  'arizona': 534,
#  'flavors': 535,
#  'stay': 536,
#  'buy': 537,
#  'run': 538,
#  'remember': 539,
#  'start': 540,
#  'pool': 541,
#  'grilled': 542,
#  'late': 543,
#  'cold': 544,
#  'chinese': 545,
#  'past': 546,
#  "you'll": 547,
#  'average': 548,
#  'easy': 549,
#  'mind': 550,
#  'days': 551,
#  'making': 552,
#  'party': 553,
#  'hit': 554,
#  'looks': 555,
#  'seen': 556,
#  'dry': 557,
#  'between': 558,
#  'game': 559,
#  'reasonable': 560,
#  'attentive': 561,
#  'morning': 562,
#  'problem': 563,
#  'ended': 564,
#  'manager': 565,
#  'beautiful': 566,
#  'anyone': 567,
#  'add': 568,
#  'extremely': 569,
#  'variety': 570,
#  'bite': 571,
#  'cake': 572,
#  'park': 573,
#  'tempe': 574,
#  'burrito': 575,
#  'trip': 576,
#  'burgers': 577,
#  'amount': 578,
#  'guys': 579,
#  'plenty': 580,
#  'saturday': 581,
#  'under': 582,
#  'ingredients': 583,
#  'az': 584,
#  'sitting': 585,
#  'butter': 586,
#  'early': 587,
#  '50': 588,
#  'french': 589,
#  'soon': 590,
#  'arrived': 591,
#  'mean': 592,
#  'near': 593,
#  'cute': 594,
#  'egg': 595,
#  'sunday': 596,
#  'potatoes': 597,
#  'show': 598,
#  'friday': 599,
#  'leave': 600,
#  "haven't": 601,
#  'along': 602,
#  'counter': 603,
#  'heard': 604,
#  'beers': 605,
#  'seriously': 606,
#  'wings': 607,
#  'eaten': 608,
#  'others': 609,
#  'tomato': 610,
#  'sometimes': 611,
#  'across': 612,
#  'working': 613,
#  'seated': 614,
#  'bill': 615,
#  'unique': 616,
#  'five': 617,
#  'believe': 618,
#  'comfortable': 619,
#  'set': 620,
#  'italian': 621,
#  'already': 622,
#  'downtown': 623,
#  'short': 624,
#  'ambiance': 625,
#  'pasta': 626,
#  'crust': 627,
#  'packed': 628,
#  'crowd': 629,
#  'quickly': 630,
#  'behind': 631,
#  '9': 632,
#  'totally': 633,
#  'onion': 634,
#  'date': 635,
#  'stopped': 636,
#  'garlic': 637,
#  'corn': 638,
#  'evening': 639,
#  'w': 640,
#  'watch': 641,
#  'shopping': 642,
#  'rather': 643,
#  'life': 644,
#  'twice': 645,
#  'tip': 646,
#  'taco': 647,
#  'expensive': 648,
#  'anyway': 649,
#  'customers': 650,
#  'itself': 651,
#  'choose': 652,
#  'pho': 653,
#  'authentic': 654,
#  'please': 655,
#  'specials': 656,
#  'ready': 657,
#  'cut': 658,
#  'main': 659,
#  '12': 660,
#  'surprised': 661,
#  'given': 662,
#  'chain': 663,
#  'space': 664,
#  'hand': 665,
#  'slow': 666,
#  'neighborhood': 667,
#  'available': 668,
#  'man': 669,
#  'head': 670,
#  'girl': 671,
#  'salads': 672,
#  'knew': 673,
#  'ones': 674,
#  'flavorful': 675,
#  'eggs': 676,
#  'rest': 677,
#  'walking': 678,
#  'weekend': 679,
#  'doing': 680,
#  'gone': 681,
#  'crispy': 682,
#  'read': 683,
#  'black': 684,
#  'chef': 685,
#  'simple': 686,
#  'waited': 687,
#  'wow': 688,
#  'offered': 689,
#  'ordering': 690,
#  'onions': 691,
#  'center': 692,
#  'including': 693,
#  'kept': 694,
#  'thanks': 695,
#  'joint': 696,
#  'feeling': 697,
#  'completely': 698,
#  'mom': 699,
#  'cup': 700,
#  'market': 701,
#  'taking': 702,
#  'yum': 703,
#  'months': 704,
#  'glad': 705,
#  'spend': 706,
#  'school': 707,
#  'bottle': 708,
#  'sausage': 709,
#  'idea': 710,
#  'needs': 711,
#  'hope': 712,
#  'mixed': 713,
#  'card': 714,
#  'bland': 715,
#  'toppings': 716,
#  'hands': 717,
#  'recently': 718,
#  'charge': 719,
#  'appetizers': 720,
#  '00': 721,
#  'located': 722,
#  'unfortunately': 723,
#  'miss': 724,
#  'salmon': 725,
#  'portion': 726,
#  'hair': 727,
#  'hungry': 728,
#  'employees': 729,
#  'change': 730,
#  'curry': 731,
#  'plates': 732,
#  'bartender': 733,
#  'low': 734,
#  'expected': 735,
#  'entire': 736,
#  'sort': 737,
#  'noodles': 738,
#  'servers': 739,
#  'yourself': 740,
#  'filled': 741,
#  'non': 742,
#  'lettuce': 743,
#  'sides': 744,
#  'desert': 745,
#  'bucks': 746,
#  'entrees': 747,
#  'wall': 748,
#  'oil': 749,
#  'grill': 750,
#  'veggies': 751,
#  'play': 752,
#  'interesting': 753,
#  'empty': 754,
#  'dark': 755,
#  'loud': 756,
#  'pieces': 757,
#  'world': 758,
#  'kinda': 759,
#  'choices': 760,
#  'moved': 761,
#  'noticed': 762,
#  'hate': 763,
#  'typical': 764,
#  'tastes': 765,
#  'yeah': 766,
#  'club': 767,
#  'veggie': 768,
#  'soft': 769,
#  "weren't": 770,
#  'thank': 771,
#  'birthday': 772,
#  'exactly': 773,
#  "aren't": 774,
#  'saying': 775,
#  'mac': 776,
#  'event': 777,
#  'giving': 778,
#  'talk': 779,
#  'spring': 780,
#  'opened': 781,
#  'together': 782,
#  'prepared': 783,
#  'unless': 784,
#  'summer': 785,
#  'office': 786,
#  'blue': 787,
#  'mouth': 788,
#  'afternoon': 789,
#  'owners': 790,
#  'phone': 791,
#  'number': 792,
#  'meals': 793,
#  'case': 794,
#  'excited': 795,
#  'crab': 796,
#  'asian': 797,
#  'understand': 798,
#  'thin': 799,
#  'stand': 800,
#  'city': 801,
#  'whatever': 802,
#  'healthy': 803,
#  'sign': 804,
#  'simply': 805,
#  'frozen': 806,
#  'note': 807,
#  'cost': 808,
#  'crowded': 809,
#  'dressing': 810,
#  'truly': 811,
#  'toast': 812,
#  'spinach': 813,
#  'chance': 814,
#  'dip': 815,
#  'share': 816,
#  'roasted': 817,
#  'pricey': 818,
#  'tasting': 819,
#  'finish': 820,
#  'tender': 821,
#  'dirty': 822,
#  'anywhere': 823,
#  'tuna': 824,
#  'outdoor': 825,
#  'company': 826,
#  'greasy': 827,
#  'cannot': 828,
#  'based': 829,
#  'ribs': 830,
#  'fair': 831,
#  'strip': 832,
#  'chili': 833,
#  'fairly': 834,
#  'single': 835,
#  'grab': 836,
#  'stuffed': 837,
#  'longer': 838,
#  'piece': 839,
#  'forward': 840,
#  'takes': 841,
#  'watching': 842,
#  'bag': 843,
#  'mix': 844,
#  'entree': 845,
#  'craving': 846,
#  'goes': 847,
#  'movie': 848,
#  'sorry': 849,
#  'stores': 850,
#  'upon': 851,
#  'homemade': 852,
#  'fabulous': 853,
#  'vegetarian': 854,
#  'pleasant': 855,
#  'tiny': 856,
#  'literally': 857,
#  'closed': 858,
#  'value': 859,
#  'cafe': 860,
#  'true': 861,
#  'tomatoes': 862,
#  'except': 863,
#  'art': 864,
#  'within': 865,
#  'sauces': 866,
#  'immediately': 867,
#  'vibe': 868,
#  'prefer': 869,
#  'buffet': 870,
#  'girls': 871,
#  'above': 872,
#  'horrible': 873,
#  'fruit': 874,
#  'bought': 875,
#  'pie': 876,
#  'middle': 877,
#  'sports': 878,
#  'view': 879,
#  'slices': 880,
#  'lady': 881,
#  'filling': 882,
#  'casual': 883,
#  'la': 884,
#  'recommended': 885,
#  'item': 886,
#  'brunch': 887,
#  'total': 888,
#  'slightly': 889,
#  'orange': 890,
#  'cook': 891,
#  'spent': 892,
#  '25': 893,
#  'paying': 894,
#  'shared': 895,
#  'mine': 896,
#  'perhaps': 897,
#  'orders': 898,
#  'iced': 899,
#  'weird': 900,
#  'easily': 901,
#  'split': 902,
#  'added': 903,
#  'pita': 904,
#  'stayed': 905,
#  "we've": 906,
#  'says': 907,
#  'seafood': 908,
#  'foods': 909,
#  'attention': 910,
#  'serving': 911,
#  'touch': 912,
#  'seats': 913,
#  'face': 914,
#  'somewhere': 915,
#  'received': 916,
#  'box': 917,
#  '11': 918,
#  'shot': 919,
#  'taken': 920,
#  'rooms': 921,
#  '99': 922,
#  'heat': 923,
#  "you've": 924,
#  'dr': 925,
#  'salty': 926,
#  'hang': 927,
#  'playing': 928,
#  'young': 929,
#  'salt': 930,
#  'seat': 931,
#  '100': 932,
#  'crazy': 933,
#  'corner': 934,
#  'certainly': 935,
#  'weeks': 936,
#  'month': 937,
#  'option': 938,
#  'beat': 939,
#  'tons': 940,
#  'lovely': 941,
#  'turkey': 942,
#  'floor': 943,
#  'mention': 944,
#  'b': 945,
#  'worst': 946,
#  'normally': 947,
#  'lack': 948,
#  'thinking': 949,
#  'talking': 950,
#  'boyfriend': 951,
#  'paid': 952,
#  'dogs': 953,
#  'cash': 954,
#  'due': 955,
#  'honestly': 956,
#  'traditional': 957,
#  'word': 958,
#  'pass': 959,
#  'matter': 960,
#  'carne': 961,
#  'hear': 962,
#  'mood': 963,
#  'finished': 964,
#  'visiting': 965,
#  'damn': 966,
#  'outstanding': 967,
#  'using': 968,
#  'vegan': 969,
#  'mushrooms': 970,
#  'pulled': 971,
#  'american': 972,
#  'drinking': 973,
#  'soda': 974,
#  'terrible': 975,
#  'pizzas': 976,
#  'turned': 977,
#  'rude': 978,
#  'bean': 979,
#  'mostly': 980,
#  'forget': 981,
#  'alone': 982,
#  'baked': 983,
#  'poor': 984,
#  'book': 985,
#  'treat': 986,
#  'die': 987,
#  'airport': 988,
#  'combo': 989,
#  'greeted': 990,
#  'honey': 991,
#  'minute': 992,
#  'standard': 993,
#  'north': 994,
#  'olive': 995,
#  'lived': 996,
#  'means': 997,
#  'tortilla': 998,
#  'peppers': 999,
#  'donuts': 1000,
#  ...}

# %%
#Lets create Sequence object

seqTrain = tokenizer.texts_to_sequences(X_train)

# %%
seqTest = tokenizer.texts_to_sequences(X_test)

# %%
#Lets pad the sequence data

from tensorflow.keras.preprocessing.sequence import pad_sequences
train_data = pad_sequences(seqTrain)
T = train_data.shape[1]
T
# Out:
# 953

# %%
testData = pad_sequences(seqTest,maxlen=T)

# %%
train_data.shape
# Out:
# (8000, 953)

# %%
testData.shape
# Out:
# (2000, 953)

# %%
len(tokenizer.word_index)
# Out:
# 27838

# %%
#Modelling Phase

import tensorflow as tf

vocabSize=len(tokenizer.word_index)
maxlen=T
embeddingDimension = 20 #Hyperparameter any value between 10 to inf (Natural no)

# %%
model = tf.keras.Sequential()
#Embedding converts sequence data into a dense vector. Embedding is responsible to preserve the semantic meaning of the sentence

model.add(tf.keras.layers.Embedding(vocabSize + 1, embeddingDimension, input_length=maxlen))

model.add(tf.keras.layers.Conv1D(filters=128, kernel_size=5, activation="relu"))

model.add(tf.keras.layers.GlobalAveragePooling1D())

model.add(tf.keras.layers.Dense(24, activation="relu"))
model.add(tf.keras.layers.Dense(12, activation="relu"))
model.add(tf.keras.layers.Dense(1, activation="sigmoid"))
# Out:
# C:\Users\micha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
#Custom Callback for early stopping

class MyThresholdCallBack(tf.keras.callbacks.Callback):
    def __init__(self,cl):
        super(MyThresholdCallBack, self).__init__()
        self.cl = cl

    def on_epoch_end(self, epoch, logs=None):
        test_score = logs["val_accuracy"]
        train_score = logs["accuracy"]

        if test_score > train_score and test_score > self.cl:
        #if test_score > self.cl:
            self.model.stop_training = True

# %%
myAccuracyMonitor = MyThresholdCallBack(cl=0.9)

# %%
model.compile(optimizer="adam",
              loss="binary_crossentropy",
              metrics=['accuracy'])

# %%
model.fit(train_data,y_train, epochs=10, validation_data=(testData,y_test), callbacks=[myAccuracyMonitor])
# Out:
# Epoch 1/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.8317 - loss: 0.4816 - val_accuracy: 0.8335 - val_loss: 0.4343
# Epoch 2/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8376 - loss: 0.4239 - val_accuracy: 0.8840 - val_loss: 0.2980
# Epoch 3/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.8975 - loss: 0.2390 - val_accuracy: 0.8945 - val_loss: 0.2560
# Epoch 4/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9414 - loss: 0.1544 - val_accuracy: 0.8990 - val_loss: 0.2689
# Epoch 5/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9687 - loss: 0.0898 - val_accuracy: 0.8980 - val_loss: 0.3055
# Epoch 6/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.9769 - loss: 0.0938 - val_accuracy: 0.8975 - val_loss: 0.3154
# Epoch 7/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9827 - loss: 0.0535 - val_accuracy: 0.8955 - val_loss: 0.3725
# Epoch 8/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9899 - loss: 0.0378 - val_accuracy: 0.8925 - val_loss: 0.4179
# Epoch 9/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9922 - loss: 0.0266 - val_accuracy: 0.8940 - val_loss: 0.4459
# Epoch 10/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9935 - loss: 0.0247 - val_accuracy: 0.8920 - val_loss: 0.4834
